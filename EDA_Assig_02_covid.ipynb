# %% [markdown]
#                                                                  Assignment #02  -- EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\ASUS\Desktop\Data Science\EDA Assign 02\COVID clinical trials (1).csv')
#df

# %%
#df
df.shape
# Out:
# (5783, 27)

# %%
#df.head()

# %%
df.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           0
# dtype: int64

# %%
#fix Acronym column
# % null values
(3303/5783)*100    # as the percentage of nulls in Acronym column is 57% we can drop this column or 
                # we can do further analysis to check its importance in the data set and accordingly decide.
# Out:
# 57.1156839010894

# %%
#df['Acronym'].unique()
#df['Acronym'].value_counts()

# %% [markdown]
# Question 01

# %% [markdown]
# On the given dataset perform the following task: 1. Read Dataset and Explore the dataset by checking shape, columns, see the first/last 'n' rows using head/tail. (n= 5,15,30) (6)

# %%
df.shape
# Out:
# (5783, 27)

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
#df.head()

# %%
#tail()

# %%
dataset_copy = df.copy()

# %%
#dataset_copy

# %%
dataset_copy.duplicated().sum()
# Out:
# 0

# %%
for column in dataset_copy:
    print("Column"," ",column," value counts is :", dataset_copy[column].value_counts())
    print("-------------------------------------------------------")
# Out:
# Column   Rank  value counts is : Rank
# 1       1
# 3864    1
# 3862    1
# 3861    1
# 3860    1
#        ..
# 1927    1
# 1926    1
# 1925    1
# 1924    1
# 5783    1
# Name: count, Length: 5783, dtype: int64
# -------------------------------------------------------
# Column   NCT Number  value counts is : NCT Number
# NCT04785898    1
# NCT04404426    1
# NCT04492514    1
# NCT04497194    1
# NCT04345419    1
#               ..
# NCT04546191    1
# NCT04357327    1
# NCT04355793    1
# NCT04510662    1
# NCT04680000    1
# Name: count, Length: 5783, dtype: int64
# -------------------------------------------------------
# Column   Title  value counts is : Title
# Study Assessing Vagus Nerve Stimulation in CoViD-19 Respiratory Symptoms                                                               2
# Study to Evaluate the Safety and Efficacy of VIRAZOLE® in Hospitalized Adult Participants With Respiratory Distress Due to COVID-19    2
# ...

# %%
for column in dataset_copy:
    print("Column"," ",column,"  uniquevalus  are :", dataset_copy[column].nunique())
    print(dataset_copy[column].unique())
    print("-------------------------")
# Out:
# Column   Rank   uniquevalus  are : 5783
# [   1    2    3 ... 5781 5782 5783]
# -------------------------
# Column   NCT Number   uniquevalus  are : 5783
# ['NCT04785898' 'NCT04595136' 'NCT04395482' ... 'NCT04740229' 'NCT04804917'
#  'NCT04680000']
# -------------------------
# Column   Title   uniquevalus  are : 5775
# ['Diagnostic Performance of the ID Now™ COVID-19 Screening Test Versus Simplexa™ COVID-19 Direct Assay'
#  'Study to Evaluate the Efficacy of COVID19-0001-USR in Patients With Mild/or Moderate COVID-19 Infection in Outpatient'
#  'Lung CT Scan Analysis of SARS-CoV2 Induced Lung Injury' ...
#  'Moderate-intensity Flow-based Yoga Effects on Cognition and Stress'
#  '3-year Follow-up of the Mind My Mind RCT'
#  'Chronic Pain Management In Primary Care Using Behavioral Health Consultants']
# -------------------------
# Column   Acronym   uniquevalus  are : 2338
# ['COVID-IDNow' 'COVID-19' 'TAC-COVID19' ... 'CRISP' 'cSLE' 'MindMyMindFU']
# -------------------------
# ...

# %%
#dataset_copy.isnull().sum()

# %%
dataset_copy.isna().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           0
# dtype: int64

# %%
# % of values missing in each column
values_list = list()
cols_list = list()
for col in dataset_copy.columns:
    pct_missing = np.mean(dataset_copy[col].isnull())*100
    cols_list.append(col)
    values_list.append(pct_missing)
pct_missing_df1 = pd.DataFrame()
pct_missing_df1['col'] = cols_list
pct_missing_df1['pct_missing'] = values_list
pct_missing_df1
# Out:
#                         col  pct_missing
# 0                      Rank     0.000000
# 1                NCT Number     0.000000
# 2                     Title     0.000000
# 3                   Acronym    57.115684
# 4                    Status     0.000000
# 5             Study Results     0.000000
# 6                Conditions     0.000000
# 7             Interventions    15.320768
# 8          Outcome Measures     0.605222
# 9     Sponsor/Collaborators     0.000000
# 10                   Gender     0.172921
# 11                      Age     0.000000
# 12                   Phases    42.555767
# 13               Enrollment     0.587930
# 14               Funded Bys     0.000000
# 15               Study Type     0.000000
# 16            Study Designs     0.605222
# 17                Other IDs     0.017292
# 18               Start Date     0.587930
# 19  Primary Completion Date     0.622514
# 20          Completion Date     0.622514
# 21             First Posted     0.000000
# ...

# %% [markdown]
#                                        Question 02

# %% [markdown]
# 2.	Filter numeric columns and summarize their statistics and do the same for categorical columns(4)

# %%
df.dtypes.value_counts()
# Out:
# object     25
# int64       1
# float64     1
# Name: count, dtype: int64

# %%
#df.select_dtypes(include=['object'])
#df.select_dtypes(exclude=['object'])
df.describe()   #numerical columns descriptive statistics
# Out:
#               Rank    Enrollment
# count  5783.000000  5.749000e+03
# mean   2892.000000  1.831949e+04
# std    1669.552635  4.045437e+05
# min       1.000000  0.000000e+00
# 25%    1446.500000  6.000000e+01
# 50%    2892.000000  1.700000e+02
# 75%    4337.500000  5.600000e+02
# max    5783.000000  2.000000e+07

# %%
df.describe(include=['object'])
# Out:
#          NCT Number                                              Title  \
# count          5783                                               5783
# unique         5783                                               5775
# top     NCT04785898  Study Assessing Vagus Nerve Stimulation in CoV...
# freq              1                                                  2
#
#          Acronym      Status         Study Results Conditions  \
# count       2480        5783                  5783       5783
# unique      2338          12                     2       3067
# top     COVID-19  Recruiting  No Results Available   COVID-19
# freq          47        2805                  5747        720
#
#                  Interventions Outcome Measures  \
# count                     4897             5748
# unique                    4337             5687
# top     Other: No intervention        Mortality
# freq                        32                5
#
# ...

# %% [markdown]
#                                      Question 03

# %% [markdown]
# 3.	Utilize str.strip() to remove leading and trailing spaces and str.replace() to correct specific character issues in the 'Conditions' column of the dataset.

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
df.columns.str.strip()
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
#df.str.replace(      )

# %% [markdown]
#                                    # Question 04

# %% [markdown]
# 4.	Solve following question by using Groupby(10)
# •	What is the average enrollment for each status?
# •	How many studies are there for each phase of the trial?
# •	What is the average enrollment for studies grouped by gender?
# •	What is the earliest start date for each study type?
# •	What is the distribution of statuses in the dataset?

# %%
df.groupby('Status')['Enrollment'].mean()
# Out:
# Status
# Active, not recruiting       60754.117871
# Approved for marketing                NaN
# Available                             NaN
# Completed                    27826.696585
# Enrolling by invitation      14319.624309
# No longer available                   NaN
# Not yet recruiting           11579.353586
# Recruiting                   10894.446346
# Suspended                     2138.222222
# Temporarily not available             NaN
# Terminated                      74.770270
# Withdrawn                        0.000000
# Name: Enrollment, dtype: float64

# %%
#How many studies are there for each phase of the trial?
df.groupby('Phases')['NCT Number'].count()
# Out:
# Phases
# Early Phase 1        46
# Not Applicable     1354
# Phase 1             234
# Phase 1|Phase 2     192
# Phase 2             685
# Phase 2|Phase 3     200
# Phase 3             450
# Phase 4             161
# Name: NCT Number, dtype: int64

# %%
#•	What is the average enrollment for studies grouped by gender?
df.groupby('Gender')['Enrollment'].mean()
# Out:
# Gender
# All       18984.795122
# Female     1365.456790
# Male        260.886364
# Name: Enrollment, dtype: float64

# %%
#•	What is the earliest start date for each study type? 
#dataset_copy['Start Date']
#dataset_copy.dtypes
#from datetime import datetime

# %%
#dataset_copy
#dataset_copy['Start Date'].value_counts()

dataset_copy['Start Date'].isnull().sum()
# Out:
# 34

# %%
#dataset_copy.dtypes

# %%
#from datetime import datetime

# %%
#pd.to_datetime(dataset_copy['Start Date'], format=["%B %d, %Y", "%B %Y"], errors='coerce')
#dataset_copy['Start Date'] = pd.to_datetime(dataset_copy['Start Date'],format = "%B %d, %Y")

#df.groupby('Study Type')['Start Date'].min()

# %%
#What is the distribution of statuses in the dataset?
df['Status'].value_counts()
# Out:
# Status
# Recruiting                   2805
# Completed                    1025
# Not yet recruiting           1004
# Active, not recruiting        526
# Enrolling by invitation       181
# Withdrawn                     107
# Terminated                     74
# Suspended                      27
# Available                      19
# No longer available            12
# Approved for marketing          2
# Temporarily not available       1
# Name: count, dtype: int64

# %% [markdown]
#                       Question 05

# %% [markdown]
# 5.	Solve following question by using qcut(10)
# •	Enrollment Quantile Categories: How are trials distributed across four quantiles based on enrollment numbers?
# •	Start Date Year Quantiles: What are the time periods represented by four quantiles of trial start years?
# •	Completion Time Frame Categories: How do trial durations distribute across four quantiles from start to completion date?
# •	Outcome Measures Count Quantiles: How are trials categorized into four quantiles based on the number of outcome measures?
# •	Trial Update Frequency Quantiles: What does the distribution of trial update frequencies look like across four quantiles?

# %%
#•	Enrollment Quantile Categories: How are trials distributed across four quantiles based on enrollment numbers?
#dataset_copy['Enrollment'].nunique()
#dataset_copy['Enrollment'].value_counts()
#dataset_copy['Enrollment'].max()
#dataset_copy['Enrollment'].min()

# %%
dataset_copy['Enrollment_categories'] = pd.qcut(dataset_copy['Enrollment'],q=4)
dataset_copy['Enrollment_categories']
dataset_copy['Enrollment_categories'].unique()
# Out:
# [(560.0, 20000000.0], (-0.001, 60.0], (170.0, 560.0], (60.0, 170.0], NaN]
# Categories (4, interval[float64, right]): [(-0.001, 60.0] < (60.0, 170.0] < (170.0, 560.0] < (560.0, 20000000.0]]

# %%
#•	Start Date Year Quantiles: What are the time periods represented by four quantiles of trial start years?

# %%
dataset_copy['Start_date_categories'] = pd.qcut(dataset_copy['Start Date'],q=4)
dataset_copy['Start_date_categories']
dataset_copy['Start_date_categories'].unique()

# %%
#•	Completion Time Frame Categories: How do trial durations distribute across four quantiles from start to completion date?

# %%
dataset_copy.columns
#df.head()
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL', 'Enrollment_categories'],
#       dtype='object')

# %%
dataset_copy['duration'] = dataset_copy['Completion Date']-dataset_copy['Start Date']
dataset_copy['duration']


dataset_copy['duration_categories'] = pd.qcut(dataset_copy['Start Date'],q=4)
dataset_copy['duration_categories']
dataset_copy['duration_categories'].unique()

# %% [markdown]
# #•	Outcome Measures Count Quantiles: How are trials categorized into four quantiles based on the number of outcome measures?

# %%
dataset_copy['Outcome Measures']
# Out:
# 0       Evaluate the diagnostic performance of the ID ...
# 1       Change on viral load results from baseline aft...
# 2       A qualitative analysis of parenchymal lung dam...
# 3       Proportion of asymptomatic subjects|Proportion...
# 4       COVID-19 by positive PCR in cord blood and / o...
#                               ...
# 5778    Number of risky drinking days|Number of patien...
# 5779    Antibiotic treatment rates in hospitalized chi...
# 5780    Perceived Stress|Task switching paradigm|Digit...
# 5781    The child's impact of mental health problems r...
# 5782    Defense and Veterans Pain Rating Scale (DVPRS)...
# Name: Outcome Measures, Length: 5783, dtype: object

# %% [markdown]
# #•	Trial Update Frequency Quantiles: What does the distribution of trial update frequencies look like across four quantiles?

# %%
dataset_copy['Outcome Measures']

# %% [markdown]
# 6.	Completion Time Frame Grouping: Apply the cut function to categorize the completion time frames of trials into distinct intervals. What are the characteristics of trials within each time frame group?

# %%
#dataset_copy['duration'].max()
#dataset_copy['duration'].min()
#dataset_copy['duration'].nunique()

# %%
dataset_copy['duration']

cut_labels =['cat1', 'cat2', 'cat3', 'cat4']
cut_bins = ['', '','','','']
dataset_copy['duration_categories'] = pd.cut(dataset_copy['Start Date'],bins=cut_bins, labels= cut_labels)
dataset_copy['duration_categories']
dataset_copy['duration_categories'].unique()

# %% [markdown]
# Enrollment Distribution Analysis: Use Matplotlib's hist() function to create a histogram visualizing the distribution of the 'Enrollment' column in the dataset.

# %%
#dataset_copy['Enrollment']
dataset_copy['Enrollment_categories'] = pd.qcut(dataset_copy['Enrollment'],q=4)
dataset_copy['Enrollment_categories']
dataset_copy['Enrollment_categories'].unique()
# Out:
# [(560.0, 20000000.0], (-0.001, 60.0], (170.0, 560.0], (60.0, 170.0], NaN]
# Categories (4, interval[float64, right]): [(-0.001, 60.0] < (60.0, 170.0] < (170.0, 560.0] < (560.0, 20000000.0]]

# %%
#plt.hist(dataset_copy['Enrollment_categories'])
#plt.show()
