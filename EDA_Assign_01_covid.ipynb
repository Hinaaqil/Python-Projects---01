# %% [markdown]
# On the given dataset perform the following task:
#
# 1.	Read Dataset and Explore the dataset by checking shape, columns, see the first/last 'n' rows using head/tail. (n= 5,15,30) (6)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\ASUS\Desktop\Data Science\EDA Assign 01\COVID clinical trials.csv')
#df

# %%
# df.head()
# df.head(15)

# %%
# df.tail()
# df.tail(30)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5783, step=1)

# %%
df.shape
# Out:
# (5783, 27)

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
# df.info

# %%
df.size
# Out:
# 156141

# %%
# df.describe()

# %%
# df.dtypes

# %%
df.dtypes.value_counts()
# Out:
# object     25
# int64       1
# float64     1
# Name: count, dtype: int64

# %% [markdown]
# 2.	Extract and document key insights by exploring column data types and applying info and describe and write down your insights inside the markdown.

# %% [markdown]
# Insights
# The dataset has 2 columns and 5783 records/rows.
# It has 25 columns of data type object, 1 column of data type int and 1 column of data type float.
# The info function is providing a concise summary of the DataFrame, including the data types of each column, the number of non-null values, and memory usage.
# The describe() function is proiding us some key descriptive statistics of the numerical columns of our data set.

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                         int64
# NCT Number                  object
# Title                       object
# Acronym                     object
# Status                      object
# Study Results               object
# Conditions                  object
# Interventions               object
# Outcome Measures            object
# Sponsor/Collaborators       object
# Gender                      object
# Age                         object
# Phases                      object
# Enrollment                 float64
# Funded Bys                  object
# Study Type                  object
# Study Designs               object
# Other IDs                   object
# Start Date                  object
# Primary Completion Date     object
# Completion Date             object
# First Posted                object
# Results First Posted        object
# Last Update Posted          object
# Locations                   object
# Study Documents             object
# URL                         object
# ...

# %%
df.dtypes.value_counts()
# Out:
# object     25
# int64       1
# float64     1
# Name: count, dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of       Rank   NCT Number                                              Title  \
# 0        1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1        2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2        3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3        4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4        5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# ...    ...          ...                                                ...
# 5778  5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# 5779  5780  NCT04681339  Antibiotic Prescription in Children Hospitaliz...
# 5780  5781  NCT04740229  Moderate-intensity Flow-based Yoga Effects on ...
# 5781  5782  NCT04804917           3-year Follow-up of the Mind My Mind RCT
# 5782  5783  NCT04680000  Chronic Pain Management In Primary Care Using ...
#
# ...

# %%
df.describe()
# Out:
#               Rank    Enrollment
# count  5783.000000  5.749000e+03
# mean   2892.000000  1.831949e+04
# std    1669.552635  4.045437e+05
# min       1.000000  0.000000e+00
# 25%    1446.500000  6.000000e+01
# 50%    2892.000000  1.700000e+02
# 75%    4337.500000  5.600000e+02
# max    5783.000000  2.000000e+07

# %% [markdown]
# 3.	Loc and iloc
# •	Select all columns for the first clinical trial in the dataset.
# •	Retrieve the Title and Status of the clinical trial with the NCT Number 'NCT04595136'.
# •	Get the Sponsor/Collaborators and Start Date for clinical trials that are Recruiting.
# •	Select the first 5 rows and columns Title, Conditions, and Outcome Measures.
# •	Find the Completion Date and URL for the last 3 clinical trials in the dataset.

# %%
# df.head(3)
# df.columns

# %%
# Select all columns for the first clinical trial in the dataset. 
df.iloc[0]
# Out:
# Rank                                                                       1
# NCT Number                                                       NCT04785898
# Title                      Diagnostic Performance of the ID Now™ COVID-19...
# Acronym                                                          COVID-IDNow
# Status                                                Active, not recruiting
# Study Results                                           No Results Available
# Conditions                                                           Covid19
# Interventions               Diagnostic Test: ID Now™ COVID-19 Screening Test
# Outcome Measures           Evaluate the diagnostic performance of the ID ...
# Sponsor/Collaborators                  Groupe Hospitalier Paris Saint Joseph
# Gender                                                                   All
# Age                                18 Years and older   (Adult, Older Adult)
# ...

# %%
# Retrieve the Title and Status of the clinical trial with the NCT Number 'NCT04595136'.
# df[df['NCT Number'] == 'NCT04595136']
df[df['NCT Number'] == 'NCT04595136'][['Title', 'Status']]
# Out:
#                                                Title              Status
# 1  Study to Evaluate the Efficacy of COVID19-0001...  Not yet recruiting

# %%
# Get the Sponsor/Collaborators and Start Date for clinical trials that are Recruiting.
df.columns
df[df['Status'] == 'Recruiting'][['Sponsor/Collaborators', 'Start Date']]
# Out:
#                                   Sponsor/Collaborators         Start Date
# 2                          University of Milano Bicocca        May 7, 2020
# 4     Centre Hospitalier Régional d'Orléans|Centre d...        May 5, 2020
# 9     Fundacion Arturo Lopez Perez|Confederación de ...      April 7, 2020
# 10                                  The Christ Hospital     April 28, 2020
# 11                         University of Milano Bicocca     April 16, 2020
# ...                                                 ...                ...
# 5776  University of Pittsburgh|U.S. National Science...   October 26, 2020
# 5777                               University of Zurich    August 25, 2020
# 5778  University of Wisconsin, Madison|National Inst...     March 23, 2020
# 5780         University of Illinois at Urbana-Champaign  February 10, 2021
# 5781  Mental Health Services in the Capital Region, ...     March 22, 2021
#
# [2805 rows x 2 columns]

# %%
# Select the first 5 rows and columns Title, Conditions, and Outcome Measures.
df.iloc[:5, df.columns.isin(['Title', 'Conditions', 'Outcome Measures'])]
# Out:
#                                                Title  \
# 0  Diagnostic Performance of the ID Now™ COVID-19...
# 1  Study to Evaluate the Efficacy of COVID19-0001...
# 2  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3  The Role of a Private Hospital in Hong Kong Am...
# 4         Maternal-foetal Transmission of SARS-Cov-2
#
#                                           Conditions  \
# 0                                            Covid19
# 1                               SARS-CoV-2 Infection
# 2                                            covid19
# 3                                              COVID
# 4  Maternal Fetal Infection Transmission|COVID-19...
#
#                                     Outcome Measures
# 0  Evaluate the diagnostic performance of the ID ...
# 1  Change on viral load results from baseline aft...
# 2  A qualitative analysis of parenchymal lung dam...
# 3  Proportion of asymptomatic subjects|Proportion...
# 4  COVID-19 by positive PCR in cord blood and / o...

# %%
# Find the Completion Date and URL for the last 3 clinical trials in the dataset.
df.tail(3)[['Completion Date', 'URL']]
# Out:
#         Completion Date                                          URL
# 5780          July 2021  https://ClinicalTrials.gov/show/NCT04740229
# 5781  December 31, 2022  https://ClinicalTrials.gov/show/NCT04804917
# 5782      February 2025  https://ClinicalTrials.gov/show/NCT04680000

# %% [markdown]
# 4.	Determine the missing values in the whole dataset and analyze missing values in each column. (10)

# %%
df.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           0
# dtype: int64

# %%
#df.columns
#df.isna().sum()

# %%
#for column in df:
    #print("column name:", column, "missing_values", df[column].isnull().sum())
    #print("...........")

# %%
pip install missingno
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

# %%
bar = msno.bar(df)

# %% [markdown]
# 5.	Calculate the sum of duplicate rows (5)

# %%
df.duplicated().sum()
#drop_duplicates()
# Out:
# 0

# %% [markdown]
# 6.	Solve following question by using conditional statements (10)
# •	How many studies have an enrollment greater than a certain threshold?

# %%
df.columns
df['Enrollment']
threshold = 15000
df[df['Enrollment'] > threshold]
# df['Study Type'].unique()
#df.Enrollment.min()
#df.Enrollment.max()
# Out:
#       Rank   NCT Number                                              Title  \
# 19      20  NCT04407585  Testing the Accuracy of a Digital Test to Diag...
# 36      37  NCT04747821  An Effectiveness Study of the Sinovac's Adsorb...
# 64      65  NCT04460274        Forecast Number of Covid-19 Cases Worldwide
# 74      75  NCT04323787  Viral Infection and Respiratory Illness Univer...
# 75      76  NCT04510207  A Study to Evaluate The Efficacy, Safety and I...
# ...    ...          ...                                                ...
# 5644  5645  NCT04566510                  LLIN Evaluation in Uganda Project
# 5656  5657  NCT04590066  Testing Multiple Behavioral Science Strategies...
# 5715  5716  NCT03871491  Azithromycin-Prevention in Labor Use Study (A-...
# 5733  5734  NCT04709263                    Heart Failure Patients Registry
# 5741  5742  NCT04565353  Testing Multiple Behavioral Science Strategies...
#
#             Acronym                  Status         Study Results  \
# ...

# %%
# •	How many clinical trials have 'No Results Available'? 
df[df['Study Results'] == 'No Results Available']
# Out:
#       Rank   NCT Number                                              Title  \
# 0        1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1        2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2        3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3        4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4        5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# ...    ...          ...                                                ...
# 5778  5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# 5779  5780  NCT04681339  Antibiotic Prescription in Children Hospitaliz...
# 5780  5781  NCT04740229  Moderate-intensity Flow-based Yoga Effects on ...
# 5781  5782  NCT04804917           3-year Follow-up of the Mind My Mind RCT
# 5782  5783  NCT04680000  Chronic Pain Management In Primary Care Using ...
#
#            Acronym                  Status         Study Results  \
# ...

# %%
# •	How many clinical trials are in an "Completed" and "Recruiting" status? 
df[(df['Status'] == 'Completed') | (df['Status'] == 'Recruiting')]
# Out:
#       Rank   NCT Number                                              Title  \
# 2        3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 4        5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 9       10  NCT04384588  COVID19-Convalescent Plasma for Treating Patie...
# 10      11  NCT04355897  CoVID-19 Plasma in Treatment of COVID-19 Patients
# 11      12  NCT04412265          Frailty in Elderly Patients With COVID-19
# ...    ...          ...                                                ...
# 5776  5777  NCT04589377  Mindfulness to Mitigate Psychological Threat a...
# 5777  5778  NCT04574466  Scaling-up Psychological Interventions With Sy...
# 5778  5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# 5780  5781  NCT04740229  Moderate-intensity Flow-based Yoga Effects on ...
# 5781  5782  NCT04804917           3-year Follow-up of the Mind My Mind RCT
#
#            Acronym      Status         Study Results  \
# ...

# %%
# •	How many clinical trials are related to 'COVID-19'? 
(df['Acronym'] == 'COVID-19').sum()
# Out:
# 47

# %%
#•	How many clinical trials started after January 1, 2020?•	How many clinical trials started after January 1, 2020?

# %%
from datetime import datetime
(df['Start Date'] > '2020-01-01').sum()
# Out:
# 5749

# %%
#df.columns
